# %%
#create model class
import torch
import torch.nn as nn

class Model(nn.Module): #sup imp
  def __init__(self, num_features):
    super().__init__() #child class calling parent using super
    self.linear1 = nn.Linear(num_features,3)
    self.relu = nn.ReLU()
    self.linear2 = nn.Linear(3,1)
    self.sigmoid = nn.Sigmoid()

  def forward(self,featuers):
    out = self.linear1(features)
    out = self.relu(out)
    out = self.linear2(out)
    out = self.sigmoid(out)

    return out

# %%
#create dataset
features = torch.rand(10,5) # 5 features
#create model
model = Model(features.shape[1])
#call model for forward pass
# model.forward(features)
model(features) # recommanded this one
# Out:
# tensor([[0.5446],
#         [0.5117],
#         [0.5223],
#         [0.5112],
#         [0.5440],
#         [0.5599],
#         [0.5448],
#         [0.5130],
#         [0.5416],
#         [0.5604]], grad_fn=<SigmoidBackward0>)

# %%
#shoe model weights
model.linear1.weight
# Out:
# Parameter containing:
# tensor([[ 0.2553,  0.2885, -0.1674,  0.3069,  0.0824],
#         [-0.2640,  0.2303, -0.2384, -0.2209,  0.0021],
#         [ 0.2615, -0.1714,  0.4291,  0.0182,  0.1172]], requires_grad=True)

# %%
model.linear2.weight
# Out:
# Parameter containing:
# tensor([[0.4826, 0.4328, 0.3475]], requires_grad=True)

# %%
#shoe model bias
model.linear.bias
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3721514675.py in <cell line: 0>()
#       1 #shoe model bias
# ----> 2 model.linear.bias
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#    1962             if name in modules:
#    1963                 return modules[name]
# -> 1964         raise AttributeError(
#    1965             f"'{type(self).__name__}' object has no attribute '{name}'"
#    1966         )
#
# AttributeError: 'Model' object has no attribute 'linear'

# %%
# !pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
from torchinfo import summary
summary(model, input_size = (10,5))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Model                                    [10, 1]                   --
# ├─Linear: 1-1                            [10, 3]                   18
# ├─ReLU: 1-2                              [10, 3]                   --
# ├─Linear: 1-3                            [10, 1]                   4
# ├─Sigmoid: 1-4                           [10, 1]                   --
# ==========================================================================================
# Total params: 22
# Trainable params: 22
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.00
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ==========================================================================================
